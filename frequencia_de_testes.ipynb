# %%
import pandas as pd
import numpy as np

# %%
arquivo_probe = pd.read_excel('Database_waystoanalyze_2021_Probe_Desktop.xlsx')
df = pd.DataFrame(arquivo_probe)
df.head()
# Out:
#    ID                          doi  Phase                  Outcome used  \
# 0  63       10.1074/jbc.M703561200  Probe   number of platform crosses
# 1  63       10.1074/jbc.M703561200  Probe      time in target quadrant
# 2  95  10.1080/0264041031000140365  Probe                      tracking
# 3  95  10.1080/0264041031000140365  Probe  number of platform crossings
# 4  95  10.1080/0264041031000140365  Probe                     distance
#
#   Medida ± S.E/S.D         Comparison (Victor) Statistical test (Victor)  \
# 0       mean ± S.E                  grupos (3)                  Incerto
# 1            % ± ?                  grupos (3)  Sem estatística mostrada
# 2                -  grupos (2) - 2 categorias                          -
# 3       mean ± S.D  grupos (2) - 2 categorias              One-way ANOVA
# 4       mean ± S.D  grupos (2) - 2 categorias              One-way ANOVA
#
#                                          Comentários  Unnamed: 8  \
# ...

# %%
outcomes = df["Outcome used"].value_counts()
outcomes
# Out:
# Outcome used
# time in target quadrant                                                        42
# number of platform crossings                                                   13
# swimming speed                                                                  9
# ACI (annulus-crossing index)                                                    8
# latency to cross platform                                                       6
# tracking                                                                        5
# time in target quadrant                                                         5
# number of entries to target quadrant                                            4
# time in opposite quadrant                                                       3
# Annulus Crosses                                                                 3
# number of platform crosses                                                      2
# ...
